# %%
import pandas as pd

df_t = pd.read_parquet("data/processed/historical_3y_to_2025-08-18_ticker.parquet")
df_c = pd.read_parquet("data/processed/historical_3y_to_2025-08-18_column.parquet")
print(df_t[:0])
print(df_c[:0])
# Out:
# Empty DataFrame
# Columns: [(AAPL, Open), (AAPL, High), (AAPL, Low), (AAPL, Close), (AAPL, Adj Close), (MSFT, Open), (MSFT, High), (MSFT, Low), (MSFT, Close), (MSFT, Adj Close), (JNJ, Open), (JNJ, High), (JNJ, Low), (JNJ, Close), (JNJ, Adj Close), (JPM, Open), (JPM, High), (JPM, Low), (JPM, Close), (JPM, Adj Close), (XOM, Open), (XOM, High), (XOM, Low), (XOM, Close), (XOM, Adj Close), (AMZN, Open), (AMZN, High), (AMZN, Low), (AMZN, Close), (AMZN, Adj Close), (GOOGL, Open), (GOOGL, High), (GOOGL, Low), (GOOGL, Close), (GOOGL, Adj Close), (TSLA, Open), (TSLA, High), (TSLA, Low), (TSLA, Close), (TSLA, Adj Close), (SPY, Open), (SPY, High), (SPY, Low), (SPY, Close), (SPY, Adj Close), (GLD, Open), (GLD, High), (GLD, Low), (GLD, Close), (GLD, Adj Close), (^GSPC, Open), (^GSPC, High), (^GSPC, Low), (^GSPC, Close), (^GSPC, Adj Close)]
# Index: []
#
# [0 rows x 55 columns]
# Empty DataFrame
# ...

# %%
df_c.tail()
# Out:
# Price             Open                                                  \
# Ticker            AAPL        MSFT         JNJ         JPM         XOM
# Date
# 2025-08-12  228.009995  523.750000  174.000000  291.500000  106.339996
# 2025-08-13  231.070007  532.109985  173.000000  293.950012  106.000000
# 2025-08-14  234.059998  522.559998  174.309998  290.579987  107.550003
# 2025-08-15  234.000000  522.770020  175.570007  294.839996  106.190002
# 2025-08-18  231.699997  521.590027  176.500000  290.000000  106.099998
#
# Price                                                                   ...  \
# Ticker            AMZN       GOOGL        TSLA         SPY         GLD  ...
# Date                                                                    ...
# 2025-08-12  222.229996  201.369995  345.000000  638.289978  308.220001  ...
# 2025-08-13  222.000000  204.130005  341.500000  644.909973  309.100006  ...
# 2025-08-14  227.399994  201.500000  335.760010  642.789978  307.929993  ...
# ...

# %%
data = pd.read_parquet("data/raw/intraday/latest_data_tickers.parquet")
data.tail()
# Out:
# Ticker                           AAPL                                      \
# Price                            Open        High         Low       Close
# Datetime
# 2025-08-19 18:26:00+00:00  230.154999  230.210007  230.039993  230.112503
# 2025-08-19 18:27:00+00:00  230.100006  230.130005  229.990005  230.009995
# 2025-08-19 18:28:00+00:00  230.009995  230.024597  229.919998  229.940002
# 2025-08-19 18:29:00+00:00  229.949905  230.059998  229.880295  230.050003
# 2025-08-19 18:30:00+00:00  229.940002  229.940002  229.940002  229.940002
#
# Ticker                                       MSFT                          \
# Price                       Adj Close        Open        High         Low
# Datetime
# 2025-08-19 18:26:00+00:00  230.112503  510.709991  510.739990  510.690002
# 2025-08-19 18:27:00+00:00  230.009995  510.720001  510.720001  510.519989
# 2025-08-19 18:28:00+00:00  229.940002  510.640015  510.700012  510.630310
# ...
